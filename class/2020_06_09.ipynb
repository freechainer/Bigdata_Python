# %%
import pandas as pd

# %%
df=pd.read_csv("data/gapminder.tsv", sep="\t")
df

#year를 기준으로 그룹화 했을때 pop의 평균을 출력
#continent를 기준으로 그룹화 했을때 gdpPercap 최댓값 출력
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
dfYear=df.groupby('year')['pop'].mean()
dfYear

# df.groupby('year').pop.mean()
# Out:
# year
# 1952    1.695040e+07
# 1957    1.876341e+07
# 1962    2.042101e+07
# 1967    2.265830e+07
# 1972    2.518998e+07
# 1977    2.767638e+07
# 1982    3.020730e+07
# 1987    3.303857e+07
# 1992    3.599092e+07
# 1997    3.883947e+07
# 2002    4.145759e+07
# 2007    4.402122e+07
# Name: pop, dtype: float64

# %%
dfContinent=df.groupby('continent')['gdpPercap'].max()
dfContinent

# df.groupby('continent').gdpPercap.max()
# Out:
# continent
# Africa       21951.21176
# Americas     42951.65309
# Asia        113523.13290
# Europe       49357.19017
# Oceania      34435.36744
# Name: gdpPercap, dtype: float64

# %%
import seaborn as sns

# %%
tips=sns.load_dataset('tips')
tips.shape
# Out:
# (244, 7)

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips['size']
tips['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# 1      4
# Name: size, dtype: int64

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# tips데이터에서 size컬럼값에 따라 그룹화 했을때 total_bill의 평균?

# tips.groupby('size')['total_bill'].mean()
tips.groupby('size').total_bill.mean()
tips.groupby('size').total_bill.min()
tips.groupby('size').total_bill.max()
tips.groupby('size').total_bill.max()-tips.groupby('size').total_bill.min()
# Out:
# size
# 1     7.00
# 2    34.80
# 3    40.48
# 4    31.84
# 5    20.50
# 6    21.12
# Name: total_bill, dtype: float64

# %%
from datetime import datetime

# %%
datetime.now()
datetime.today()
# Out:
# datetime.datetime(2020, 6, 9, 10, 33, 53, 165193)

# %%
t1=datetime.now()
t1
t2=datetime(1993,6,16)
t3=datetime(1970,12,12,13,24,34)

# %%
t1-t2
# Out:
# datetime.timedelta(days=9855, seconds=38191, microseconds=405089)

# %%
ebola=pd.read_csv("data/country_timeseries.csv")
ebola
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
df=pd.DataFrame({
    'od':['05/01/20', '06/01/20']
})
df
# Out:
#          od
# 0  05/01/20
# 1  06/01/20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   od      2 non-null      object
# dtypes: object(1)
# memory usage: 144.0+ bytes

# %%
df['dt1']=pd.to_datetime(df['od'], format='%m/%d/%y')
df['dt2']=pd.to_datetime(df['od'], format='%d/%m/%y')
df['dt3']=pd.to_datetime(df['od'], format='%y/%m/%d')
print(df)
# print(df.info())
# Out:
#          od        dt1        dt2        dt3
# 0  05/01/20 2020-05-01 2020-01-05 2005-01-20
# 1  06/01/20 2020-06-01 2020-01-06 2006-01-20

# %%
ebola['dateDt']=pd.to_datetime(ebola['Date'])
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
ebola1=pd.read_csv("data/country_timeseries.csv", parse_dates=['Date'])
ebola1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
df
# Out:
#          od        dt1        dt2        dt3
# 0  05/01/20 2020-05-01 2020-01-05 2005-01-20
# 1  06/01/20 2020-06-01 2020-01-06 2006-01-20

# %%
df.dt3[0].year
df.dt3[0].month
df.dt3[0].day
# Out:
# 20

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
ebola.head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
del ebola['dataDt']

# %%
ebola.head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
ebola[['Date', 'dateDt']].head()
# ebola.loc[0:4, ['Date', 'dateDt']]
# Out:
#          Date     dateDt
# 0    1/5/2015 2015-01-05
# 1    1/4/2015 2015-01-04
# 2    1/3/2015 2015-01-03
# 3    1/2/2015 2015-01-02
# 4  12/31/2014 2014-12-31

# %%
ebola['dateDt'][4].year
# Out:
# 2014

# %%
# ebola['dateDt'].year
ebola['dateDt'].dt.year
ebola['dateDt'].dt.month
ebola['dateDt'].dt.day
# Out:
# 0       5
# 1       4
# 2       3
# 3       2
# 4      31
#        ..
# 117    27
# 118    26
# 119    25
# 120    24
# 121    22
# Name: dateDt, Length: 122, dtype: int64

# %%
# ebola['year']=ebola['dateDt'].dt.year
# ebola['month']=ebola['dateDt'].dt.month
ebola['day']=ebola['dateDt'].dt.day
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
ebola.head()
ebola.iloc[-5: , :5]
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 117  3/27/2014   27         103.0            8.0                6.0
# 118  3/26/2014   26          86.0            NaN                NaN
# 119  3/25/2014   25          86.0            NaN                NaN
# 120  3/24/2014   24          86.0            NaN                NaN
# 121  3/22/2014   22          49.0            NaN                NaN

# %%
print(ebola['dateDt'].min())
# Out:
# 2014-03-22 00:00:00

# %%
ebola['outbreakD']=ebola['dateDt']-ebola['dateDt'].min()
ebola[['Date','Day','outbreakD']].head()
# Out:
#          Date  Day outbreakD
# 0    1/5/2015    5  289 days
# 1    1/4/2015    4  288 days
# 2    1/3/2015    3  287 days
# 3    1/2/2015    2  286 days
# 4  12/31/2014   31  284 days

# %%
ebola.head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015    5        2776.0            NaN            10030.0
# 1    1/4/2015    4        2775.0            NaN             9780.0
# 2    1/3/2015    3        2769.0         8166.0             9722.0
# 3    1/2/2015    2           NaN         8157.0                NaN
# 4  12/31/2014   31        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    ...  Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedStates  Deaths_Spain  \
# ...

# %%
# 에볼라 데이터의 각 컬럼 단위로 null 값 개수를 출력하시오

# %%
numMissong=ebola.shape[0]-ebola.count()
numMissong
# Out:
# Date                     0
# Day                      0
# Cases_Guinea            29
# Cases_Liberia           39
# Cases_SierraLeone       35
# Cases_Nigeria           84
# Cases_Senegal           97
# Cases_UnitedStates     104
# Cases_Spain            106
# Cases_Mali             110
# Deaths_Guinea           30
# Deaths_Liberia          41
# Deaths_SierraLeone      35
# Deaths_Nigeria          84
# Deaths_Senegal         100
# Deaths_UnitedStates    104
# Deaths_Spain           106
# Deaths_Mali            110
# dtype: int64

# %%
np.sum(ebola.isnull())
# Out:
# Date                     0
# Day                      0
# Cases_Guinea            29
# Cases_Liberia           39
# Cases_SierraLeone       35
# Cases_Nigeria           84
# Cases_Senegal           97
# Cases_UnitedStates     104
# Cases_Spain            106
# Cases_Mali             110
# Deaths_Guinea           30
# Deaths_Liberia          41
# Deaths_SierraLeone      35
# Deaths_Nigeria          84
# Deaths_Senegal         100
# Deaths_UnitedStates    104
# Deaths_Spain           106
# Deaths_Mali            110
# dtype: int64

# %%
np.sum(np.sum(ebola.isnull()))
# Out:
# 1214

# %%
np.count_nonzero(ebola.isnull())
# ebola.isnull() : null => True(1), not null => False(0)
ebola.isnull()
# Out:
#       Date    Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    False  False         False           True              False
# 1    False  False         False           True              False
# 2    False  False         False          False              False
# 3    False  False          True          False               True
# 4    False  False         False          False              False
# ..     ...    ...           ...            ...                ...
# 117  False  False         False          False              False
# 118  False  False         False           True               True
# 119  False  False         False           True               True
# 120  False  False         False           True               True
# 121  False  False         False           True               True
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0             True           True                True         True
# ...

# %%
np.count_nonzero(ebola['Cases_Guinea'].isnull())
np.sum(ebola['Cases_Guinea'].isnull())
# Out:
# 29

# %%
ebola.Cases_Guinea.value_counts()
# Out:
# 86.0      3
# 112.0     2
# 390.0     2
# 495.0     2
# 2597.0    1
#          ..
# 235.0     1
# 231.0     1
# 226.0     1
# 224.0     1
# 2776.0    1
# Name: Cases_Guinea, Length: 88, dtype: int64

# %%
np.sum(ebola['Cases_Guinea'].isnull())
ebola['Cases_Guinea']=ebola['Cases_Guinea'].fillna(0)
np.sum(ebola['Cases_Guinea'].isnull())
# Out:
# 0

# %%
np.sum(ebola.Cases_Liberia.isnull())
# Out:
# 39

# %%
el=ebola.Cases_Liberia[0:10]
el
# Out:
# 0       NaN
# 1       NaN
# 2    8166.0
# 3    8157.0
# 4    8115.0
# 5    8018.0
# 6       NaN
# 7    7977.0
# 8       NaN
# 9    7862.0
# Name: Cases_Liberia, dtype: float64

# %%
el.fillna(method='ffill')
el.fillna(method='bfill')
# Out:
# 0    8166.0
# 1    8166.0
# 2    8166.0
# 3    8157.0
# 4    8115.0
# 5    8018.0
# 6    7977.0
# 7    7977.0
# 8    7862.0
# 9    7862.0
# Name: Cases_Liberia, dtype: float64

# %%
#결측값처리 : 살리는 것, 죽이는 것(삭제)
#살리는것 : (fill, bfill, 임의의값, 선형회귀, knn, svm, ...)
#학번 임꺽정 90 80 80 80 80 ..
#학번 홍길동 100 90 NA 80 90 ..

# %%
el.interpolate()
# Out:
# 0       NaN
# 1       NaN
# 2    8166.0
# 3    8157.0
# 4    8115.0
# 5    8018.0
# 6    7997.5
# 7    7977.0
# 8    7919.5
# 9    7862.0
# Name: Cases_Liberia, dtype: float64

# %%
ebola=pd.read_csv("data/country_timeseries.csv",
                 parse_dates=['Date'])

# %%
ebola.shape
# Out:
# (122, 18)

# %%
ebolaD=ebola.dropna() #결측값이 있으면 해당 행을 제거
ebolaD.shape
# Out:
# (1, 18)

# %%
ebola['Cases_multiple']=ebola['Cases_Guinea']+ebola['Cases_Liberia']+ebola['Cases_SierraLeone']

# %%
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
# ebola[['Cases_multiple','Cases_Guinea','Cases_Liberia','Cases_SierraLeone']]
ebola.loc[:,['Cases_multiple','Cases_Guinea','Cases_Liberia','Cases_SierraLeone']]
# Out:
#      Cases_multiple  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0               NaN        2776.0            NaN            10030.0
# 1               NaN        2775.0            NaN             9780.0
# 2           20657.0        2769.0         8166.0             9722.0
# 3               NaN           NaN         8157.0                NaN
# 4           20478.0        2730.0         8115.0             9633.0
# ..              ...           ...            ...                ...
# 117           117.0         103.0            8.0                6.0
# 118             NaN          86.0            NaN                NaN
# 119             NaN          86.0            NaN                NaN
# 120             NaN          86.0            NaN                NaN
# 121             NaN          49.0            NaN                NaN
#
# [122 rows x 4 columns]

# %%
ebola.Cases_Guinea.sum(skipna=True)
ebola.Cases_Guinea.sum(skipna=False)
# Out:
# nan

# %%
banks=pd.read_csv("data/banklist.csv", parse_dates=[5,6])
banks
# banks.info()
# Out:
#                                              Bank Name         City  ST  \
# 0                  Washington Federal Bank for Savings      Chicago  IL
# 1      The Farmers and Merchants State Bank of Argonia      Argonia  KS
# 2                                  Fayette County Bank   Saint Elmo  IL
# 3    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI
# 4                                       First NBC Bank  New Orleans  LA
# ..                                                 ...          ...  ..
# 550                                 Superior Bank, FSB     Hinsdale  IL
# 551                                Malta National Bank        Malta  OH
# 552                    First Alliance Bank & Trust Co.   Manchester  NH
# 553                  National State Bank of Metropolis   Metropolis  IL
# 554                                   Bank of Honolulu     Honolulu  HI
#
#       CERT                Acquiring Institution Closing Date Updated Date
# ...

# %%
banks['closing_year']=banks['Closing Date'].dt.year
# banks['closing_quarter']=banks['Closing Date'].dt.quarter

# %%
banks['closing_year']
#각 연도별로 파산한 은행의 개수 출력
# closingYear=banks.groupby('closing_year').size()
# Out:
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
#        ...
# 550    2001
# 551    2001
# 552    2001
# 553    2000
# 554    2000
# Name: closing_year, Length: 555, dtype: int64

# %%
closingYear
# Out:
# closing_year
# 2000      2
# 2001      4
# 2002     11
# 2003      3
# 2004      4
# 2007      3
# 2008     25
# 2009    140
# 2010    157
# 2011     92
# 2012     51
# 2013     24
# 2014     18
# 2015      8
# 2016      5
# 2017      8
# dtype: int64

# %%
closingYear=banks.groupby('closing_year').size()
closingYear
closingQuarter=banks.groupby('closing_quarter').size()
closingQuarter
# Out:
# closing_quarter
# 1    135
# 2    138
# 3    153
# 4    129
# dtype: int64

# %%
closingYearQ=banks.groupby(['closing_year', 'closing_quarter']).size()
closingYearQ
# Out:
# closing_year  closing_quarter
# 2000          4                   2
# 2001          1                   1
#               2                   1
#               3                   2
# 2002          1                   6
#               2                   2
#               3                   1
#               4                   2
# 2003          1                   1
#               2                   1
#               4                   1
# 2004          1                   3
#               2                   1
# 2007          1                   1
#               3                   1
#               4                   1
# 2008          1                   2
#               2                   2
#               3                   9
#               4                  12
# 2009          1                  21
#               2                  24
#               3                  50
#               4                  45
# 2010          1                  41
# ...

# %%
import matplotlib.pyplot as plt

# %%
closingYear.plot()

# %%
closingYearQ.plot()

# %%
closingQuarter.plot()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
TSLA=pd.read_csv('TSLA.csv', parse_dates=[0])
TSLA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       252 non-null    datetime64[ns]
#  1   Open       252 non-null    float64
#  2   High       252 non-null    float64
#  3   Low        252 non-null    float64
#  4   Close      252 non-null    float64
#  5   Adj Close  252 non-null    float64
#  6   Volume     252 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 13.9 KB

# %%
TSLA
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2019-06-10  210.250000  216.940002  209.009995  212.880005  212.880005
# 1   2019-06-11  219.139999  220.899994  213.500000  217.100006  217.100006
# 2   2019-06-12  222.949997  223.380005  209.000000  209.259995  209.259995
# 3   2019-06-13  210.380005  214.899994  207.509995  213.910004  213.910004
# 4   2019-06-14  211.250000  216.649994  210.399994  214.919998  214.919998
# ..         ...         ...         ...         ...         ...         ...
# 247 2020-06-02  894.700012  908.659973  871.000000  881.559998  881.559998
# 248 2020-06-03  888.119995  897.940002  880.099976  882.960022  882.960022
# 249 2020-06-04  889.880005  895.750000  858.440002  864.380005  864.380005
# 250 2020-06-05  877.840027  886.520020  866.200012  885.659973  885.659973
# 251 2020-06-08  919.000000  950.000000  909.159973  949.919983  949.919983
#
#        Volume
# 0    10585000
# 1    11653500
# 2    15186200
# ...

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
TSLA
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2019-06-10  210.250000  216.940002  209.009995  212.880005  212.880005
# 1   2019-06-11  219.139999  220.899994  213.500000  217.100006  217.100006
# 2   2019-06-12  222.949997  223.380005  209.000000  209.259995  209.259995
# 3   2019-06-13  210.380005  214.899994  207.509995  213.910004  213.910004
# 4   2019-06-14  211.250000  216.649994  210.399994  214.919998  214.919998
# 5   2019-06-17  215.479996  227.000000  214.270004  225.029999  225.029999
# 6   2019-06-18  228.720001  234.740005  222.559998  224.740005  224.740005
# 7   2019-06-19  225.110001  227.770004  221.059998  226.429993  226.429993
# 8   2019-06-20  223.000000  226.899994  216.350006  219.619995  219.619995
# 9   2019-06-21  216.220001  222.179993  215.500000  221.860001  221.860001
# 10  2019-06-24  223.240005  225.860001  221.020004  223.639999  223.639999
# ...

# %%
# 1. 각 컬럼별
# 1)정규화
# 2)표준화

# 2.각 컬럼별
# 최대/최소/4분위수 조사
#최대-최소(차이)

# 3. 종가에 대해
# - 월 별 평균 출력 -> 시각화
# - 분기별 평균 출력 -> 시각화

# 4. open대비 close 시점에 주가가 상승한 날이 총 몇일?

# %%
print(np.max(TSLA))    # 컬럼별 최대
print(np.min(TSLA))     # 컬럼별 최소

print(np.max(TSLA)-np.min(TSLA))       # 최대-최소(차이)
# Out:
# Date         2020-06-08 00:00:00
# Open                       923.5
# High                      968.99
# Low                       909.16
# Close                     949.92
# Adj Close                 949.92
# Volume                  60938800
# month                         12
# year                        2020
# quarter                        4
# dtype: object
# Date         2019-06-10 00:00:00
# Open                      210.25
# High                       214.9
# Low                       207.51
# Close                     209.26
# Adj Close                 209.26
# Volume                   2465600
# month                          1
# year                        2019
# quarter                        1
# dtype: object
# Date         364 days 00:00:00
# Open                    713.25
# High                    754.09
# Low                     701.65
# Close                   740.66
# Adj Close               740.66
# Volume                58473200
# month                       11
# ...

# %%
# TSLA['Date'].dt.year
# TSLA['year']=TSLA['Date'].dt.year
# tslaYear=TSLA.groupby('year').size()
# tslaYear

# TSLA['Date'].dt.month
# TSLA.Close.groupby(TSLA['Date'].dt.month).mean().plot()
# TSLA['Date'].dt.month
#tslaMonth=TSLA.groupby('month')
#tslaMonth
# TSLA.Close.groupby(tslaMonth).mean()

# TSLA['Date'].dt.quarter
# TSLA['quarter']=TSLA['Date'].dt.quarter
# tslaQuarter=TSLA.groupby('quarter').size()
# tslaQuarter

TSLA['Date'].dt.quarter
TSLA.Close.groupby(TSLA['Date'].dt.quarter).mean().plot()

# %%
TSLA.groupby('month').Close.mean().plot()

# %%
for col in TSLA.columns:
    print(TSLA[col].quantile([0.25, 0.50, 0.75]))
# Out:
# 0.25   2019-09-08 06:00:00
# 0.50   2019-12-05 12:00:00
# 0.75   2020-03-09 06:00:00
# Name: Date, dtype: datetime64[ns]
# 0.25    240.990005
# 0.50    352.400009
# 0.75    645.007507
# Name: Open, dtype: float64
# 0.25    244.614994
# 0.50    356.759995
# 0.75    673.630005
# Name: High, dtype: float64
# 0.25    236.082501
# 0.50    348.079987
# 0.75    621.630005
# Name: Low, dtype: float64
# 0.25    241.515000
# 0.50    352.195007
# 0.75    655.210006
# Name: Close, dtype: float64
# 0.25    241.515000
# 0.50    352.195007
# 0.75    655.210006
# Name: Adj Close, dtype: float64
# 0.25     6883650.0
# 0.50    10551700.0
# 0.75    16257425.0
# Name: Volume, dtype: float64
# 0.25     4.0
# 0.50     7.0
# 0.75    10.0
# Name: month, dtype: float64
# 0.25    2019.0
# 0.50    2019.0
# 0.75    2020.0
# Name: year, dtype: float64
# 0.25    2.0
# 0.50    3.0
# 0.75    4.0
# Name: quarter, dtype: float64

# %%
# 4. open대비 close 시점에 주가가 상승한 날이 총 몇일?

# %%
TSLA
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2019-06-10  210.250000  216.940002  209.009995  212.880005  212.880005
# 1   2019-06-11  219.139999  220.899994  213.500000  217.100006  217.100006
# 2   2019-06-12  222.949997  223.380005  209.000000  209.259995  209.259995
# 3   2019-06-13  210.380005  214.899994  207.509995  213.910004  213.910004
# 4   2019-06-14  211.250000  216.649994  210.399994  214.919998  214.919998
# 5   2019-06-17  215.479996  227.000000  214.270004  225.029999  225.029999
# 6   2019-06-18  228.720001  234.740005  222.559998  224.740005  224.740005
# 7   2019-06-19  225.110001  227.770004  221.059998  226.429993  226.429993
# 8   2019-06-20  223.000000  226.899994  216.350006  219.619995  219.619995
# 9   2019-06-21  216.220001  222.179993  215.500000  221.860001  221.860001
# 10  2019-06-24  223.240005  225.860001  221.020004  223.639999  223.639999
# ...

# %%
# for day in TSLA.columns:
#     day =['Open'] < ['Close']
#     print(day)

# type(TSLA['Open']
# type(print(TSLA['Close']))
TSLA['Open'] < TSLA['Close']
TSLA[TSLA['Open'] < TSLA['Close']]
TSLA[TSLA['Open'] < TSLA['Close']].count()
len(TSLA[TSLA['Open'] < TSLA['Close']])
# Out:
# 137
